# %%
import os

root = '/Users/Sean/MIDS'

# %%
for dirname, subdirs, files in os.walk(root):
    print ('Found directory: ' + dirname)
    for f in files:
        print '\t' + f
# Out:
# Found directory: /Users/Sean/MIDS
# 	.DS_Store
# Found directory: /Users/Sean/MIDS/205
# 	#Vagrantfile#
# 	.DS_Store
# 	bootstrap.sh
# 	jdk-8u60-macosx-x64-2.dmg
# 	Vagrantfile
# 	Word count example.ipynb
# Found directory: /Users/Sean/MIDS/205/.ipynb_checkpoints
# 	Word count example-checkpoint.ipynb
# Found directory: /Users/Sean/MIDS/205/.vagrant
# Found directory: /Users/Sean/MIDS/205/.vagrant/machines
# Found directory: /Users/Sean/MIDS/205/.vagrant/machines/default
# Found directory: /Users/Sean/MIDS/205/.vagrant/machines/default/virtualbox
# 	action_provision
# 	action_set_name
# 	creator_uid
# 	id
# 	index_uuid
# 	private_key
# 	synced_folders
# Found directory: /Users/Sean/MIDS/205/hospital_data
# 	.DS_Store
# 	Complications - Hospital.csv
# 	Complications - National.csv
# 	HCAHPS - Hospital.csv
# 	Healthcare Associated Infections - Hospital.csv
# 	Hospital General Information.csv
# 	Readmissions and Deaths - Hospital.csv
# Found directory: /Users/Sean/MIDS/205/MIDS
# ...
