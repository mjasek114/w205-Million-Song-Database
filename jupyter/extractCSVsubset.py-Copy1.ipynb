# %%
# From:
#   https://hdfgroup.org/wp/2015/03/from-hdf5-datasets-to-apache-spark-rdds/
# Specialized to MIDS W205-2 (Fall 2015)

# Modules needed below:
#   Pandas
#   h5py
#   psycopg2
#   MySQL-python

import os
import os.path
import h5py
import sys

mainRoot = os.path.expanduser('~/MIDS/mss/') 
mssRoot = os.path.expanduser('~/MIDS/mss/data/')
blocksRoot = os.path.expanduser('~/MIDS/mss/blocks/')
resultsRoot = os.path.expanduser('~/MIDS/mss/results/')

llss = os.listdir(mainRoot)

if blocksRoot.split('/')[-2] not in llss:
    os.mkdir(blocksRoot)
if resultsRoot.split('/')[-2] not in llss:
    os.mkdir(resultsRoot)
if mssRoot.split('/')[-2] not in llss:
    os.mkdir(mssRoot)
    
    

filesPerBlock = 100  # Gives about 30MB/file. Should use larger size in production.

minPartitions = 4 #minimum number of partitions for use by Spark

# %%
# Configure spark to work
import os
import sys

spark_home = os.environ.get('SPARK_HOME', None)
if not spark_home:
    raise ValueError('SPARK_HOME environment variable is not set')
sys.path.insert(0, os.path.join(spark_home, 'python'))
sys.path.insert(0, os.path.join(spark_home, 'python/lib/py4j-0.8.2.1-src.zip'))

#execfile(os.path.join(spark_home, 'python/pyspark/shell.py'))

# %%
def getFileNames(dataRoot, verbose = True):
	
	fileStructure = os.walk(dataRoot)
	
	h5Files = []
	for entry in fileStructure:
		thisPath = entry[0]
		thisFileList = entry[2]
		#print thisPath, thisFileList

		for ff in thisFileList:
			if ff.endswith('.h5'):
				h5Files.append(os.path.join(thisPath,ff))
				if verbose:
					print os.path.join(thisPath,ff)
	return h5Files

# %%
def buildReferenceCSV(dataRoot = None, publish = True, verbose = True):
	'''
	"Walks" the file tree and finds all of the HD5 files in the tree under dataRoot
	(assumes these are from the million song database)
	'''
	
	if not dataRoot:
		dataRoot = blocksRoot
    
	h5Files = getFileNames(dataRoot, verbose = verbose)

	if publish:
		csvFileName = os.path.join(dataRoot,'Hd5Extracts.csv')
		oFile = open(csvFileName, 'w')
        
	
	for ff in h5Files:

		pubString = ff
#		pubString += ', '
#		pubString += 'analysis, '
#		pubString += 'key \n'   # Key of the song, not key of the hash

		if publish:
			oFile.write(pubString + '\n')

		if verbose:
			print pubString

	return csvFileName

# %%
def nodeToDict(inputLine, verbose = False):
    '''
    This function is intended for use in Spark.
    Inputs a line (probably from the reference CSV)
    and extracts some important info 
    
    Returns a list of dictionaries, each dictionary has all "analysis" fields in the song.
    It's possible that all songs don't have exactly the same fields.
    '''
    import h5py
    parsedLine = inputLine.split(',')
    thisH5File = h5py.File(parsedLine[0])
    
    if parsedLine[0].split('/')[-1].startswith('Chunk'):
        thisBlockSongList = thisH5File['songs']

        songInfo = []

        for thisSong in thisBlockSongList:
            # There are 3 categories of data in this set.  Grab stuff from all
            # of them
            analysisDataSet = thisH5File['songs'][thisSong]['analysis']['songs']
            metadataDataSet = thisH5File['songs'][thisSong]['metadata']['songs']
            musicbrainzDataSet = thisH5File['songs'][thisSong]['musicbrainz']['songs']

            outDict = dict()

            for measurement1 in analysisDataSet.dtype.names:
                value = analysisDataSet[measurement1][0]
                
                if len(str(value)) > 0:
                    outDict[measurement1] = value
                else:
                    outDict[measurement1] = 'NA'

                

            for measurement2 in musicbrainzDataSet.dtype.names:
                value = musicbrainzDataSet[measurement2][0]
    
                if len(str(value)) > 0:
                    outDict[measurement2] = value
                else:
                    outDict[measurement2] = 'NA'


            for measurement3 in metadataDataSet.dtype.names:
                value = metadataDataSet[measurement3][0]            ##

                if len(str(value)) > 0:
                    outDict[measurement3] = value
                else:
                    outDict[measurement3] = 'NA'
                
            #if verbose:
            #print outTuple
            songInfo.append(outDict)

        return songInfo

# %%
#  Process in Spark

from pyspark import SparkContext
from optparse import OptionParser
from datetime import datetime as dt
print 'Establishing Spark Context'

# Kill the context if it already exists
if 'sc' in dir():
    sc.stop()

sc = SparkContext(appName="SparkHDF5")

csvFileName = buildReferenceCSV(dataRoot = blocksRoot, verbose = False)

print 'Fetching all file names'
timeNow = dt.now().isoformat()
file_paths = sc.textFile(os.path.join(blocksRoot,'Hd5Extracts.csv'),minPartitions=minPartitions)

print 'Mapping RDD'
rdd = file_paths.flatMap(nodeToDict)
results = rdd.take(1000)

print 'Results Generated.'

sc.stop()
# Out:
# Establishing Spark Context
# Fetching all file names
# Mapping RDD
# Results Generated.

# %%
# Get unique column names
# and write results out as a csv

import csv

allParameters = []

# This loop gets all the names of the measurements (key, tempo,etc) making this code 
# not dependent on every song having exactly the same structure
for song in results:
    [allParameters.append(measure) for measure in song.keys()]
    allParameters = list(set(allParameters))   # keep only unique measurement names 
    
# Write dictionaries as .csv file
with open(os.path.join(resultsRoot,'MSD_Flat.csv'), 'wb') as output_file:
    dict_writer = csv.DictWriter(output_file, allParameters)
    dict_writer.writeheader()
    dict_writer.writerows(results)

print '\n\n\tComplete.  CSV written to ', os.path.join(resultsRoot,'MSD_Flat.csv'), '\n\n'
# Out:
# 	Complete.  CSV written to  /home/james/MIDS/mss/results/MSD_Flat.csv

# %%
# Import the flat csv file into pandas
# This will facilitate any hands-on analyses we might want to do
# And makes setting up a postgres table REALLY easy

import MySQLdb
import pandas as pd

# Connect to a local MySQL server using the username "james" (no password) 
# and the database mss.
dbConnection=MySQLdb.connect(host="localhost",user="james",db="mss")

# Turn our csv file into a Pandas data frame.  
df = pd.read_csv(os.path.join(resultsRoot,'MSD_Flat.csv'))

# Tell pandas to load this dataframe as a MySQL table
df2 = df.astype(object).where(pd.notnull(df), None)
df2.to_sql("MSS", con= dbConnection, flavor = 'mysql', if_exists = 'replace')
# Out:
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 9
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_location' at row 44
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 94
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 167
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 217
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 233
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 236
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 266
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 302
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 315
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 336
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 336
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 337
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 363
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 400
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 409
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 451
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 471
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 526
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'artist_name' at row 586
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 720
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 790
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'release' at row 854
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 875
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 945
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 'title' at row 964
#   cur.executemany(insert_query, data)
# /usr/lib/python2.7/dist-packages/pandas/io/sql.py:264: Warning: Data truncated for column 
# 10                                                NaN             192322
# 11                                        Paw Paw, WV              16253
# 12                          Yiewsley, London, England               1630
# 13                                Geneva, Switzerland              29437
# 14                                        Orlando, FL              54273
# 15                                                NaN              23700
# 16                                     J�ping, Sweden              10180
# 17                                     Birmingham, AL              20690
# 18                                                NaN             409537
# 19                                                NaN              64896
# 20                                    Antibes, France              12566
# 21                                            GERMANY             116499
# 22                                                NaN              38573
# 23                                                NaN              16367
# 24                                       New York, NY             129713
# 25                                    Los Angeles, Ca              41583
# 26                                    East Orange, NJ               1968
# 27                                   Washington, D.C.               9718
# 28                                                NaN               5417
# 29                                        Chicago, IL               7041
# 30                                         Newark, NJ                368
# 31                                      Brest, France              26669
# 32                             Shelby, North Carolina               3363
# 33                                                NaN              17528
# 34                                                NaN              41644
# 35                                           Helsinki             309423
# 36                                                NaN             291877
# 37                               NASHVILLE, Tennessee             304663
# 38                                                NaN               7565
# 39                                                NaN             505851
# 40                                                NaN              90217
# 41                                   Harlem, New York               1237
# 42                                           Missouri             477060
# 43  Bézu, comme Superdupont, ne connait qu&#039;un...             304198
# 44                                       Stamford, CT              43762
# 45                                    Los Angeles, CA               1459
# 46                                                NaN             141951
# 47                                 New York, New York               5732
# 48                           West Hartlepool, England             185262
# 49                                                NaN              13447
# 50                                          İngiltere               4081
# 51                                                NaN              40912
# 52                                        Waukesha WI              11528
# 53                                                                 17864
# 54                             Boston, Massachusettes              16929
# 55                                                NaN             330695
# 56                                          Tyler, AL             149177
# 57                                    Gainesville, FL               4996
# 58                          UK - England - South West              51197
# 59                                    London, England                 25
#                                                   ...                ...
#
#     idx_artist_terms  time_signature_confidence  artist_longitude  \
# 0                  0                      0.968               NaN
# 1                  0                      0.774         -72.09647
# 2                  0                      1.000               NaN
# 3                  0                      0.619               NaN
# 4                  0                      0.350         -73.85678
# 5                  0                      0.922          -1.97406
# 6                  0                      0.000          -1.20788
# 7                  0                      0.986         -89.10827
# 8                  0                      0.000               NaN
# 9                  0                      0.841               NaN
# 10                 0                      0.000               NaN
# 11                 0                      0.000               NaN
# 12                 0                      0.000          -0.47261
# 13                 0                      0.000           6.14270
# 14                 0                      0.473               NaN
# 15                 0                      0.000               NaN
# 16                 0                      0.391               NaN
# 17                 0                      1.000         -86.81150
# 18                 0                      0.260               NaN
# 19                 0                      0.277               NaN
# 20                 0                      0.841           7.12123
# 21                 0                      0.000          10.45415
# 22                 0                      0.213               NaN
# 23                 0                      0.000               NaN
# 24                 0                      0.579         -74.00712
# 25                 0                      0.502        -118.24532
# 26                 0                      0.446         -74.20991
# 27                 0                      0.368               NaN
# 28                 0                      0.501               NaN
# 29                 0                      0.946         -87.63241
# 30                 0                      1.000               NaN
# 31                 0                      0.509          -4.48622
# 32                 0                      0.000               NaN
# 33                 0                      1.000               NaN
# 34                 0                      0.441               NaN
# 35                 0                      0.426               NaN
# 36                 0                      1.000               NaN
# 37                 0                      0.496         -86.77836
# 38                 0                      0.245               NaN
# 39                 0                      0.660               NaN
# 40                 0                      0.434               NaN
# 41                 0                      1.000         -73.94540
# 42                 0                      0.039         -92.43659
# 43                 0                      1.000               NaN
# 44                 0                      0.000         -73.54223
# 45                 0                      0.119        -118.24532
# 46                 0                      0.288               NaN
# 47                 0                      1.000         -74.00712
# 48                 0                      0.000          -1.23230
# 49                 0                      0.299               NaN
# 50                 0                      0.757               NaN
# 51                 0                      1.000               NaN
# 52                 0                      1.000         -88.23546
# 53                 0                      0.934               NaN
# 54                 0                      1.000               NaN
# 55                 0                      0.157               NaN
# 56                 0                      0.656         -86.89775
# 57                 0                      0.152               NaN
# 58                 0                      0.611          -1.97406
# 59                 0                      0.831          -0.12714
#                  ...                        ...               ...
#
#     idx_segments_loudness_max_time  idx_sections_start  artist_playmeid
# 0                                0                   0              881 ...
# 1                                0                   0             4664 ...
# 2                                0                   0               -1 ...
# 3                                0                   0            38963 ...
# 4                                0                   0             7529 ...
# 5                                0                   0            18452 ...
# 6                                0                   0               -1 ...
# 7                                0                   0            98091 ...
# 8                                0                   0            16411 ...
# 9                                0                   0            34193 ...
# 10                               0                   0               -1 ...
# 11                               0                   0             8624 ...
# 12                               0                   0               -1 ...
# 13                               0                   0            63046 ...
# 14                               0                   0             5414 ...
# 15                               0                   0               -1 ...
# 16                               0                   0            83087 ...
# 17                               0                   0               -1 ...
# 18                               0                   0           178039 ...
# 19                               0                   0               -1 ...
# 20                               0                   0            13427 ...
# 21                               0                   0               -1 ...
# 22                               0                   0               -1 ...
# 23                               0                   0            92268 ...
# 24                               0                   0           128443 ...
# 25                               0                   0             1757 ...
# 26                               0                   0              460 ...
# 27                               0                   0             6595 ...
# 28                               0                   0            43168 ...
# 29                               0                   0            66483 ...
# 30                               0                   0               -1 ...
# 31                               0                   0               -1 ...
# 32                               0                   0            15188 ...
# 33                               0                   0            59132 ...
# 34                               0                   0              778 ...
# 35                               0                   0               -1 ...
# 36                               0                   0            57070 ...
# 37                               0                   0             7992 ...
# 38                               0                   0               -1 ...
# 39                               0                   0               -1 ...
# 40                               0                   0             6630 ...
# 41                               0                   0               66 ...
# 42                               0                   0               -1 ...
# 43                               0                   0               -1 ...
# 44                               0                   0               -1 ...
# 45                               0                   0               -1 ...
# 46                               0                   0            16395 ...
# 47                               0                   0             1010 ...
# 48                               0                   0               -1 ...
# 49                               0                   0             1373 ...
# 50                               0                   0             1447 ...
# 51                               0                   0               -1 ...
# 52                               0                   0            20696 ...
# 53                               0                   0             1773 ...
# 54                               0                   0             2938 ...
# 55                               0                   0               -1 ...
# 56                               0                   0               -1 ...
# 57                               0                   0               -1 ...
# 58                               0                   0            45172 ...
# 59                               0                   0              594 ...
#                                ...                 ...              ...
#
# [1000 rows x 53 columns]

# %%
# Tell pandas to load this dataframe as a MySQL table
import pandas as pd
import os
import os.path
dfBillboard = pd.read_csv(os.path.join(resultsRoot,'billboard.csv'))
dfBillboard = df.astype(object).where(pd.notnull(df), None)
dfBillboard.to_sql("billboard", con= dbConnection, flavor = 'mysql', if_exists = 'replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c117b63ed1cc> in <module>()
#       3 import os
#       4 import os.path
# ----> 5 dfBillboard = pd.read_csv(os.path.join(resultsRoot,'billboard.csv'))
#       6 dfBillboard = df.astype(object).where(pd.notnull(df), None)
#       7 dfBillboard.to_sql("billboard", con= dbConnection, flavor = 'mysql', if_exists = 'replace')
#
# NameError: name 'resultsRoot' is not defined
